# %% [markdown]
# # Pandas计算（常用内建函数）

# %% [markdown]
# ## pct_change()
# 计算百分比变化Percentage Change

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

stock1 = pd.read_excel('sz50.xlsx',sheetname='600036.XSHG', index_col='datetime')

# %%
one_day_change = stock1.close.pct_change()
print(one_day_change)
five_day_change = stock1.close.pct_change(5)
print(five_day_change)
ten_day_change = stock1.close.pct_change(10)
print(ten_day_change)
# Out:
# datetime
# 2017-01-03 15:00:00         NaN
# 2017-01-04 15:00:00    0.001587
# 2017-01-05 15:00:00    0.006194
# 2017-01-06 15:00:00   -0.007158
# 2017-01-09 15:00:00   -0.001730
# 2017-01-10 15:00:00    0.000000
# 2017-01-11 15:00:00    0.000578
# 2017-01-12 15:00:00    0.002743
# 2017-01-13 15:00:00    0.011661
# 2017-01-16 15:00:00    0.019212
# 2017-01-17 15:00:00   -0.005864
# 2017-01-18 15:00:00    0.007584
# 2017-01-19 15:00:00   -0.003764
# 2017-01-20 15:00:00    0.002658
# 2017-01-23 15:00:00   -0.003768
# 2017-01-24 15:00:00    0.019471
# 2017-01-25 15:00:00    0.001099
# 2017-01-26 15:00:00    0.006313
# 2017-02-03 15:00:00   -0.015276
# 2017-02-06 15:00:00   -0.005817
# 2017-02-07 15:00:00   -0.001115
# 2017-02-08 15:00:00    0.001116
# 2017-02-09 15:00:00    0.008080
# 2017-02-10 15:00:00    0.008015
# 2017-02-13 15:00:00    0.004113
# 2017-02-14 15:00:00   -0.006281
# 2017-02-15 15:00:00    0.014290
# 2017-02-16 15:00:00    0.000000
# 2017-02-17 15:00:00   -0.005690
# 2017-02-20 15:00:00    0.020981
#                          ...
# 2017-10-10 15:00:00    0.001537
# 2017-10-11 15:00:00   -0.003070
# 2017-10-12 15:00:00    0.012703
# 2017-10-13 15:00:00   -0.006462
# 2017-10-16 15:00:00    0.025538
# 2017-10-17 15:00:00    0.005969
# 2017-10-18 15:00:00    0.002967
# 2017-10-19 15:00:00   -0.000370
# 2017-10-20 15:00:00   -0.012206
# 2017-10-23 15:00:00   -0.010110
# 2017-10-24 15:00:00    0.004539
# 2017-10-25 15:00:00    0.006778
# 2017-10-26 15:00:00   -0.009351
# 2017-10-27 15:00:00    0.058429
# 2017-10-30 15:00:00   -0.011059
# 2017-10-31 15:00:00   -0.024799
# 2017-11-01 15:00:00   -0.007398
# 2017-11-02 15:00:00    0.004099
# 2017-11-03 15:00:00    0.001856
# 2017-11-06 15:00:00   -0.016670
# 2017-11-07 15:00:00    0.015822
# 2017-11-08 15:00:00    0.002225
# 2017-11-09 15:00:00   -0.000740
# 2017-11-10 15:00:00    0.000000
# 2017-11-13 15:00:00    0.022126
# 2017-11-14 15:00:00    0.012680
# 2017-11-15 15:00:00   -0.005008
# 2017-11-16 15:00:00    0.007910
# 2017-11-17 15:00:00    0.045572
# 2017-11-20 15:00:00    0.039065
# Name: close, Length: 215, dtype: float64
# datetime
# 2017-01-03 15:00:00         NaN
# 2017-01-04 15:00:00         NaN
# 2017-01-05 15:00:00         NaN
# 2017-01-06 15:00:00         NaN
# 2017-01-09 15:00:00         NaN
# 2017-01-10 15:00:00   -0.001154
# 2017-01-11 15:00:00   -0.002161
# 2017-01-12 15:00:00   -0.005583
# 2017-01-13 15:00:00    0.013266
# 2017-01-16 15:00:00    0.034523
# 2017-01-17 15:00:00    0.028456
# 2017-01-18 15:00:00    0.035658
# 2017-01-19 15:00:00    0.028938
# 2017-01-20 15:00:00    0.019781
# 2017-01-23 15:00:00   -0.003211
# 2017-01-24 15:00:00    0.022191
# 2017-01-25 15:00:00    0.015612
# 2017-01-26 15:00:00    0.025885
# 2017-02-03 15:00:00    0.007536
# 2017-02-06 15:00:00    0.005463
# 2017-02-07 15:00:00   -0.014839
# 2017-02-08 15:00:00   -0.014823
# 2017-02-09 15:00:00   -0.013093
# 2017-02-10 15:00:00    0.010249
# 2017-02-13 15:00:00    0.020340
# 2017-02-14 15:00:00    0.015063
# 2017-02-15 15:00:00    0.028420
# 2017-02-16 15:00:00    0.020177
# 2017-02-17 15:00:00    0.006307
# 2017-02-20 15:00:00    0.023211
#                          ...
# 2017-10-10 15:00:00    0.015986
# 2017-10-11 15:00:00    0.025259
# 2017-10-12 15:00:00    0.046440
# 2017-10-13 15:00:00    0.025503
# 2017-10-16 15:00:00    0.030268
# 2017-10-17 15:00:00    0.034827
# 2017-10-18 15:00:00    0.041093
# 2017-10-19 15:00:00    0.027654
# 2017-10-20 15:00:00    0.021712
# 2017-10-23 15:00:00   -0.013803
# 2017-10-24 15:00:00   -0.015205
# 2017-10-25 15:00:00   -0.011462
# 2017-10-26 15:00:00   -0.020344
# 2017-10-27 15:00:00    0.049710
# 2017-10-30 15:00:00    0.048704
# 2017-10-31 15:00:00    0.018076
# 2017-11-01 15:00:00    0.003740
# 2017-11-02 15:00:00    0.017368
# 2017-11-03 15:00:00   -0.037011
# 2017-11-06 15:00:00   -0.042475
# 2017-11-07 15:00:00   -0.002589
# 2017-11-08 15:00:00    0.007080
# 2017-11-09 15:00:00    0.002227
# 2017-11-10 15:00:00    0.000370
# 2017-11-13 15:00:00    0.039838
# 2017-11-14 15:00:00    0.036622
# 2017-11-15 15:00:00    0.029140
# 2017-11-16 15:00:00    0.038049
# 2017-11-17 15:00:00    0.085355
# 2017-11-20 15:00:00    0.103342
# Name: close, Length: 215, dtype: float64
# datetime
# 2017-01-03 15:00:00         NaN
# 2017-01-04 15:00:00         NaN
# 2017-01-05 15:00:00         NaN
# 2017-01-06 15:00:00         NaN
# 2017-01-09 15:00:00         NaN
# 2017-01-10 15:00:00         NaN
# 2017-01-11 15:00:00         NaN
# 2017-01-12 15:00:00         NaN
# 2017-01-13 15:00:00         NaN
# 2017-01-16 15:00:00         NaN
# 2017-01-17 15:00:00    0.027269
# 2017-01-18 15:00:00    0.033420
# 2017-01-19 15:00:00    0.023193
# 2017-01-20 15:00:00    0.033309
# 2017-01-23 15:00:00    0.031200
# 2017-01-24 15:00:00    0.051278
# 2017-01-25 15:00:00    0.051826
# 2017-01-26 15:00:00    0.055572
# 2017-02-03 15:00:00    0.027465
# 2017-02-06 15:00:00    0.002234
# 2017-02-07 15:00:00    0.007022
# 2017-02-08 15:00:00    0.000558
# 2017-02-09 15:00:00    0.012453
# 2017-02-10 15:00:00    0.017862
# 2017-02-13 15:00:00    0.025914
# 2017-02-14 15:00:00    0.000000
# 2017-02-15 15:00:00    0.013176
# 2017-02-16 15:00:00    0.006819
# 2017-02-17 15:00:00    0.016620
# 2017-02-20 15:00:00    0.044023
#                          ...
# 2017-10-10 15:00:00   -0.001915
# 2017-10-11 15:00:00    0.005808
# 2017-10-12 15:00:00    0.011924
# 2017-10-13 15:00:00    0.009657
# 2017-10-16 15:00:00    0.041072
# 2017-10-17 15:00:00    0.051370
# 2017-10-18 15:00:00    0.067390
# 2017-10-19 15:00:00    0.075378
# 2017-10-20 15:00:00    0.047769
# 2017-10-23 15:00:00    0.016047
# 2017-10-24 15:00:00    0.019092
# 2017-10-25 15:00:00    0.029160
# 2017-10-26 15:00:00    0.006747
# 2017-10-27 15:00:00    0.072501
# 2017-10-30 15:00:00    0.034229
# 2017-10-31 15:00:00    0.002596
# 2017-11-01 15:00:00   -0.007765
# 2017-11-02 15:00:00   -0.003329
# 2017-11-03 15:00:00    0.010859
# 2017-11-06 15:00:00    0.004161
# 2017-11-07 15:00:00    0.015440
# 2017-11-08 15:00:00    0.010847
# 2017-11-09 15:00:00    0.019634
# 2017-11-10 15:00:00   -0.036654
# 2017-11-13 15:00:00   -0.004329
# 2017-11-14 15:00:00    0.033937
# 2017-11-15 15:00:00    0.036426
# 2017-11-16 15:00:00    0.040360
# 2017-11-17 15:00:00    0.085757
# 2017-11-20 15:00:00    0.147297
# Name: close, Length: 215, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,7))
plt.plot(one_day_change.iloc[-50:], label='one')
plt.plot(five_day_change.iloc[-50:], label='five')
plt.plot(ten_day_change.iloc[-50:], label='ten')
plt.legend()
plt.show()

# %% [markdown]
# ## cov()
# 计算协方差Covariance

# %%
stock2 = pd.read_excel('sz50.xlsx',sheetname='600050.XSHG', index_col='datetime')
stock3 = pd.read_excel('sz50.xlsx',sheetname='601318.XSHG', index_col='datetime')

# %%
five_day_df = pd.concat([stock1.close.pct_change(5),stock2.close.pct_change(5),stock3.close.pct_change(5)],keys=['stock1','stock2','stock3'],axis=1)

# %%
print(five_day_df.tail())
# Out:
#                        stock1    stock2    stock3
# datetime
# 2017-11-14 15:00:00  0.036622 -0.014538  0.077249
# 2017-11-15 15:00:00  0.029140  0.018947  0.071039
# 2017-11-16 15:00:00  0.038049 -0.029293  0.100700
# 2017-11-17 15:00:00  0.085355 -0.034102  0.076982
# 2017-11-20 15:00:00  0.103342 -0.016064  0.079239

# %%
print(five_day_df.cov())
# Out:
#           stock1    stock2    stock3
# stock1  0.001271  0.000139  0.000806
# stock2  0.000139  0.003739  0.000608
# stock3  0.000806  0.000608  0.001203

# %% [markdown]
# ## corr()
# 计算相关系数Correlation

# %%
# 相关系数
correlation = five_day_df.corr()
print(correlation)
# Out:
#           stock1    stock2    stock3
# stock1  1.000000  0.085415  0.652129
# stock2  0.085415  1.000000  0.315773
# stock3  0.652129  0.315773  1.000000

# %%
# spearman排序相关性
spearman = five_day_df.corr(method='spearman')
print(spearman)
# Out:
#           stock1    stock2    stock3
# stock1  1.000000 -0.003432  0.659493
# stock2 -0.003432  1.000000  0.165067
# stock3  0.659493  0.165067  1.000000

# %% [markdown]
# ## rank()
# 数据排序

# %%
print(five_day_df.tail())
# Out:
#                        stock1    stock2    stock3
# datetime
# 2017-11-14 15:00:00  0.036622 -0.014538  0.077249
# 2017-11-15 15:00:00  0.029140  0.018947  0.071039
# 2017-11-16 15:00:00  0.038049 -0.029293  0.100700
# 2017-11-17 15:00:00  0.085355 -0.034102  0.076982
# 2017-11-20 15:00:00  0.103342 -0.016064  0.079239

# %%
# 正向纵序
print(five_day_df.tail().rank(axis=0))
# Out:
#                      stock1  stock2  stock3
# datetime
# 2017-11-14 15:00:00     2.0     4.0     3.0
# 2017-11-15 15:00:00     1.0     5.0     1.0
# 2017-11-16 15:00:00     3.0     2.0     5.0
# 2017-11-17 15:00:00     4.0     1.0     2.0
# 2017-11-20 15:00:00     5.0     3.0     4.0

# %%
#横向倒序
print(five_day_df.rank(axis=1, ascending=False).tail())
# Out:
#                      stock1  stock2  stock3
# datetime
# 2017-11-14 15:00:00     2.0     3.0     1.0
# 2017-11-15 15:00:00     2.0     3.0     1.0
# 2017-11-16 15:00:00     2.0     3.0     1.0
# 2017-11-17 15:00:00     1.0     3.0     2.0
# 2017-11-20 15:00:00     1.0     3.0     2.0

# %% [markdown]
# ## rolling()
# 滚动计算

# %%
rolling = stock1.close.rolling(window=20)

# %%
print(rolling.mean().tail())
# Out:
# datetime
# 2017-11-14 15:00:00    108.1320
# 2017-11-15 15:00:00    108.2855
# 2017-11-16 15:00:00    108.4850
# 2017-11-17 15:00:00    109.0060
# 2017-11-20 15:00:00    109.8100
# Name: close, dtype: float64

# %%
plt.figure(figsize=(15,7))
plt.plot(rolling.mean())
plt.plot(stock1.close)
plt.show()

# %% [markdown]
# ## apply()
# 调用自定义函数

# %%
import numpy as np

def cal_range(array):
    return array.max() - array.min()

print(stock1.rolling(10).apply(cal_range).tail())
# Out:
#                      close   high    low   open      volume
# datetime
# 2017-11-14 15:00:00   5.63   5.63   5.70   4.83  45715400.0
# 2017-11-15 15:00:00   5.63   5.63   5.70   5.55  45715400.0
# 2017-11-16 15:00:00   5.95   5.63   5.70   5.55  45599200.0
# 2017-11-17 15:00:00  11.06  10.17   8.06   6.83  55576000.0
# 2017-11-20 15:00:00  13.96  13.92  10.34  10.82  55576000.0

# %% [markdown]
# ## Computing rolling pairwise covariances and correlations

# %%
## 50天滚动的五日收益协方差

cov_50 = five_day_df.rolling(50).cov()

print(cov_50.tail(6))
# Out:
#                               stock1    stock2    stock3
# datetime
# 2017-11-17 15:00:00 stock1  0.000743  0.000248  0.000773
#                     stock2  0.000248  0.001945  0.000923
#                     stock3  0.000773  0.000923  0.001420
# 2017-11-20 15:00:00 stock1  0.000931  0.000207  0.000865
#                     stock2  0.000207  0.001925  0.000875
#                     stock3  0.000865  0.000875  0.001438

# %%
## 50天滚动的五日收益相关性

corr_50 = five_day_df.rolling(50,).corr()
print(corr_50.tail(6))
# Out:
#                               stock1    stock2    stock3
# datetime
# 2017-11-17 15:00:00 stock1  1.000000  0.206307  0.752711
#                     stock2  0.206307  1.000000  0.555120
#                     stock3  0.752711  0.555120  1.000000
# 2017-11-20 15:00:00 stock1  1.000000  0.154276  0.747151
#                     stock2  0.154276  1.000000  0.525728
#                     stock3  0.747151  0.525728  1.000000

# %%
plt.figure(figsize=(15,7))
plt.plot(corr_50.unstack()['stock1','stock3'])
plt.show()

# %% [markdown]
# ## aggregate
# 聚合，主要用于处理数据运算(诸如统计平均值,求和等)，并返回计算后的运算结果。

# %%
# 对多只股票进行求和
import numpy as np
sum_agg = five_day_df.rolling(10).aggregate(np.sum)
print(sum_agg.tail())
# Out:
#                        stock1    stock2    stock3
# datetime
# 2017-11-14 15:00:00  0.025171  0.478886  0.434446
# 2017-11-15 15:00:00  0.050571  0.396198  0.438228
# 2017-11-16 15:00:00  0.071251  0.293819  0.494201
# 2017-11-17 15:00:00  0.193616  0.243951  0.563012
# 2017-11-20 15:00:00  0.339433  0.238697  0.643087

# %%
# 对stock1进行多个不同的计算
multi_agg = five_day_df.stock1.rolling(10).agg([np.sum, np.mean, np.std])
print(multi_agg.tail())
# Out:
#                           sum      mean       std
# datetime
# 2017-11-14 15:00:00  0.025171  0.002517  0.026701
# 2017-11-15 15:00:00  0.050571  0.005057  0.028006
# 2017-11-16 15:00:00  0.071251  0.007125  0.029727
# 2017-11-17 15:00:00  0.193616  0.019362  0.034364
# 2017-11-20 15:00:00  0.339433  0.033943  0.036102

# %%
# 针对不要数据用不同算法
multi_algo = five_day_df.rolling(20).agg({'stock1' : np.sum,
       'stock2' : np.std,
       'stock3' : np.mean})

print(multi_algo.tail())
# Out:
#                        stock1    stock2    stock3
# datetime
# 2017-11-14 15:00:00  0.171306  0.049099  0.046782
# 2017-11-15 15:00:00  0.159352  0.048760  0.047016
# 2017-11-16 15:00:00  0.169747  0.046769  0.049882
# 2017-11-17 15:00:00  0.233389  0.046673  0.052029
# 2017-11-20 15:00:00  0.350535  0.046850  0.053621

# %%
# resample成周线后用agg获取所需要的数据
print(stock1.resample('W').agg({'high':'max','low':'min', 'close':'last', 'open':'first'}).tail())
# Out:
#               high     low   close    open
# datetime
# 2017-10-29  112.29  105.38  112.13  106.66
# 2017-11-05  111.93  106.22  107.98  111.05
# 2017-11-12  109.49  104.87  108.02  107.34
# 2017-11-19  117.67  108.46  117.24  108.46
# 2017-11-26  122.50  116.20  121.82  116.92

# %% [markdown]
# ## expanding
# expanding不会返回NaN，功能与rolling相似。

# %%
sn = pd.Series([1, 2, np.nan, 3, np.nan, 4])

# %%
print(sn.expanding().sum())
# Out:
# 0     1.0
# 1     3.0
# 2     3.0
# 3     6.0
# 4     6.0
# 5    10.0
# dtype: float64

# %%
print(sn.cumsum())
# Out:
# 0     1.0
# 1     3.0
# 2     NaN
# 3     6.0
# 4     NaN
# 5    10.0
# dtype: float64

# %%
print(sn.cumsum().fillna(method='ffill'))
# Out:
# 0     1.0
# 1     3.0
# 2     3.0
# 3     6.0
# 4     6.0
# 5    10.0
# dtype: float64
